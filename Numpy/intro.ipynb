# %%
import numpy as np

# %%
scaler_one = np.array(3)

# %%
scaler_one
# Out:
# array(3)

# %%
vector_two = np.array([1, 2, 3])
vector_two
# Out:
# array([1, 2, 3])

# %%
print(vector_two.size)
print(vector_two.shape)
print(vector_two.dtype)
# Out:
# 3
# (3,)
# int64

# %%
values_propagator = np.array([[[1, 2, 3], [1, 2, 3], [1, 2, 3]], [[1, 2, 3], [1, 2, 3], [1, 2, 3]]])
dm_container = values_propagator.shape

# %%
print(dm_container[2])
# Out:
# 3

# %%
np.ones((4,3), dtype='int32')
# Out:
# np.int32(1)

# %%
np.random.randn(4,3)
# Out:
# array([[ 2.0785096 , -1.1152909 , -1.12246076],
#        [-0.07310603, -0.48826943,  0.29729499],
#        [-1.45474979,  1.84755794,  1.42540304],
#        [ 0.15243219,  0.00881921,  1.02970055]])

# %%
np.random.random_sample(values_propagator.shape)
# Out:
# array([[[0.49807097, 0.75667354, 0.65501953],
#         [0.93174618, 0.95892753, 0.96503416],
#         [0.8614945 , 0.96822433, 0.61493683]],
#
#        [[0.49985021, 0.30223545, 0.78344791],
#         [0.31097582, 0.38668244, 0.26041365],
#         [0.43956256, 0.28688451, 0.23465506]]])

# %%
#random integer
np.random.randint(1, 9, size=(2,2))
# Out:
# array([[4, 3],
#        [8, 1]])

# %%
#identity matrix
np.identity(3)
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])
